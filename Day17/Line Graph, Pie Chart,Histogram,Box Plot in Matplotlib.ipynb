# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Line Graph

# %%
gas_data=pd.read_csv("gas_prices.csv")

# %%
gas_data
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
gas_data
plt.title("Gas Prices Over Time in USD ")

# plt.plot(gas_data.Year,gas_data.Italy,label ="Italy",marker="o",color="green",markersize=5)
# plt.plot(gas_data.Year,gas_data.USA,label ="United State",marker="o",color="magenta",markersize=5)
# plt.plot(gas_data.Year,gas_data.Germany,label="Germany",marker="o",color="orange",markersize=5)
# plt.plot(gas_data.Year,gas_data['South Korea'],label="South Korea",marker="o",color="black",markersize=5)

# for country in gas_data:
#     if country!="Year":
#         plt.plot(gas_data.Year,gas_data[country],marker=".")

# countries=["Australia",'Canada','USA']
# for country in gas_data:
#     if country in countries:
#         plt.plot(gas_data.Year,gas_data[country],marker=".")


plt.xlabel("Year",fontsize=15)
plt.ylabel("Price in USD Dollars",fontsize=15)
plt.xticks(gas_data.Year[::3])
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Load Fifa Data

# %%
fifa=pd.read_csv("Fifa.csv")

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %% [markdown]
# # Histogram

# %%
bins=[30,40,50,60,70,80,90,100]
plt.hist(fifa.Overall,bins=bins,color="Green")
plt.xticks(bins)
plt.title("Distribution of Players Skills level in FIFA 2018")
plt.ylabel("Number oF Players")
plt.xlabel("Skills Level")
plt.show()

# %% [markdown]
# # Pie Chart

# %%
fifa.head(5)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
left=fifa.loc[fifa['Preferred Foot']=="Left"].count()[0]
right=fifa.loc[fifa['Preferred Foot']=="Right"].count()[0]
labels=["Left","Right"]
colors=['#1CD0BB',"#6E7C7C"]
plt.pie([left,right],labels=labels,colors=colors,autopct="%.2f")
plt.title("Foot Preference of FIFA Players")
plt.show()

# %%
fifa.Weight=[int(x.strip("lbs")) if type(x)==str else x for x in fifa.Weight]

# %%
light=fifa.loc[fifa.Weight <125 ].count()[0]

plt.style.use('ggplot')

light_medium=fifa.loc[(fifa.Weight >=125 ) & (fifa.Weight <=150)].count()[0]
medium=fifa.loc[(fifa.Weight >=150 ) & (fifa.Weight <=175)].count()[0]
high_medium=fifa.loc[(fifa.Weight >=175 ) & (fifa.Weight <=200)].count()[0]
high=fifa.loc[fifa.Weight >=200].count()[0]

weights=[light,light_medium,medium,high_medium,high]
labels=["Under 125","125-150","150-175","175-200","over 200"]
explode=(.4,.2,.0,.0,.4)
plt.title("Weight Distribution of FIFA Players in (LBS)")
plt.pie(weights,labels=labels,autopct="%.2f",pctdistance=0.8,explode=explode)
plt.show()

# %% [markdown]
# # Box Plot

# %%
barcelona = fifa.loc[fifa.Club == "FC Barcelona"]['Overall']
madrid = fifa.loc[fifa.Club == "Real Madrid"]['Overall']
revs = fifa.loc[fifa.Club == "New England Revolution"]['Overall']


labels=['FC Barcelona','Real Madrid','NE Revolution']


plt.boxplot([barcelona,madrid,revs],labels=labels)


plt.title('Professional Soccer Team Comparison')
plt.ylabel('FIFA Overall Rating')


plt.show()
